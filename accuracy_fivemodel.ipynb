# %%
import ActionRecognitionModels.trainlog
import os.path

LOGDIR = os.path.expanduser("~") + '/notebook/201907/videoActionRecognitionStudy/data/logs/trainlog_0708/'

# %%
ActionRecognitionModels.trainlog.plot(LOGDIR + "c3d-training-1562556444.6385152.log")
ActionRecognitionModels.trainlog.printAccuracyList(LOGDIR + "c3d-training-1562556444.6385152.log")
# Out:
# 0.3125
# 0.5875

# %%
ActionRecognitionModels.trainlog.plot(LOGDIR + "conv_3d-training-1562545783.1055586.log")
ActionRecognitionModels.trainlog.printAccuracyList(LOGDIR + "conv_3d-training-1562545783.1055586.log")
# Out:
# 0.30416666753590105
# 0.5614583291113376

# %%
ActionRecognitionModels.trainlog.plot(LOGDIR + "lstm-training-1562317425.676043.log")
ActionRecognitionModels.trainlog.printAccuracyList(LOGDIR + "lstm-training-1562317425.676043.log")
# Out:
# 0.74375
# 0.933333332836628

# %%
ActionRecognitionModels.trainlog.plot(LOGDIR + "mlp-training-1562317190.2512693.log")
ActionRecognitionModels.trainlog.printAccuracyList(LOGDIR + "mlp-training-1562317190.2512693.log")
# Out:
# 0.7458333373069763
# 0.9249999985098839
